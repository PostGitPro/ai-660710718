# %% [markdown]
# # สร้างข้อมูลหลัก (Master Dataset) ที่จะใช้ตลอดบทเรียน 🎯

# %% [markdown]
# import libary

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
#  อ่าน file student.csv

# %%
df = pd.read_csv("student.csv")

# %% [markdown]
# กำหนด seed ข้อมูลนักศึกษา 42 คน

# %%
np.random.seed(42)

# %% [markdown]
#  ข้อมูลพื้นฐานของนักศีกษาทั้ง 42 คน

# %%
student_data = {
    'รหัสนักศึกษา': [f'64{str(i).zfill(3)}' for i in range(1, 21)],
    'ชื่อ': ['สมชาย', 'สมหญิง', None, 'สมศักดิ์', 'สมใจ', 'กานต์', 'กิตติ',
             'จิรา', 'ชนาธิป', 'ดารา', 'ธีระ', 'นภา', 'บุญมี', 'ปรีชา',
             'พิมพ์', 'ภูมิ', 'มานี', 'ยุพา', 'รัตนา', 'ลัดดา'],
    'อายุ': [20, 21, None, 22, 19, 150, 21, 20, 23, 21,  # 150 = outlier
            None, 22, 20, 21, 22, 19, 20, 21, None, 22],
    'เพศ': ['ชาย', 'หญิง', 'Male', 'ช', 'ญ', 'ชาย', 'หญิง', 'F', 'M', 'หญิง',
            None, 'ชาย', 'หญิง', 'ชาย', 'Female', 'ช', 'ญ', 'หญิง', 'ชาย', None],
    'คณะ': ['วิทยาศาสตร์', 'วิทย์', 'Science', 'คณะวิทยาศาสตร์', 'วิศวะ',
            'Engineering', 'วิศวกรรม', 'ศิลปศาสตร์', 'Arts', 'ศิลป์',
            None, 'วิทย์', 'วิศวฯ', 'Liberal Arts', 'Sci',
            'วิทยาศาสตร์', 'วิศวกรรมศาสตร์', None, 'ศิลปศาสตร์', 'Science'],
    'GPA': [3.21, 3.45, 3.67, -1, 3.89, 3.12, 4.5, 2.98, 3.34, 3.56,
            3.78, None, 3.23, 3.45, 3.67, 3.89, 3.01, 3.23, None, 3.45],
    'ส่วนสูง_cm': [170, 165, 175, 168, 160, 172, 158, 180, 163, 167,
                  None, 171, 169, 164, 162, 173, 166, 161, 174, 168],
    'น้ำหนัก_kg': [65, 58, None, 70, 52, 75, 48, 82, 55, 60,
                  68, None, 72, 54, 56, 78, 62, 50, 76, 64],
    'ชั่วโมงเรียน_ต่อสัปดาห์': [15, 20, 25, 10, 30, 12, 35, 18, 22, 28,
                              None, 16, 24, 19, 26, 14, 21, 27, None, 23]
}

# %% [markdown]
#  สร้าง DataFrame

# %%
df_master = pd.DataFrame(student_data)

# %% [markdown]
#  เช็คจำนวน Row และ Col ของ DataFrame

# %%
df_master.shape
# Out:
# (20, 9)

# %% [markdown]
#  ดูข้อมูลตัวอย่าง

# %%
df_master.head()
# Out:
#   รหัสนักศึกษา      ชื่อ  อายุ   เพศ             คณะ   GPA  ส่วนสูง_cm  \
# 0        64001     สมชาย  20.0   ชาย     วิทยาศาสตร์  3.21       170.0
# 1        64002    สมหญิง  21.0  หญิง           วิทย์  3.45       165.0
# 2        64003      None   NaN  Male         Science  3.67       175.0
# 3        64004  สมศักดิ์  22.0     ช  คณะวิทยาศาสตร์ -1.00       168.0
# 4        64005      สมใจ  19.0     ญ           วิศวะ  3.89       160.0
#
#    น้ำหนัก_kg  ชั่วโมงเรียน_ต่อสัปดาห์
# 0        65.0                     15.0
# 1        58.0                     20.0
# 2         NaN                     25.0
# 3        70.0                     10.0
# 4        52.0                     30.0

# %% [markdown]
#  เพิ่มวันที่ลงทะเบียน

# %%
base_date = datetime(2024, 1, 15)

# %%
base_date
# Out:
# datetime.datetime(2024, 1, 15, 0, 0)

# %%
df_master['วันที่ลงทะเบียน'] = [base_date + timedelta(days=np.random.randint(-30, 30))
                                for _ in range(20)]

# %% [markdown]
#  แสดงผลข้อมูลต่างๆ

# %%
print("="*50)
print("🎯 ข้อมูลหลัก (Master Dataset) ที่จะใช้ตลอดบทเรียน")
print("="*50)
print(df_master)
print("\n📊 สรุปปัญหาที่พบในข้อมูล:")
print(f"- ค่าหายทั้งหมด: {df_master.isnull().sum().sum()} ค่า")
print(f"- อายุผิดปกติ: {df_master[df_master['อายุ'] > 100]['อายุ'].values if any(df_master['อายุ'] > 100) else 'ไม่มี'}")
print(f"- GPA ผิดปกติ: {df_master[(df_master['GPA'] < 0) | (df_master['GPA'] > 4)]['GPA'].values if any((df_master['GPA'] < 0) | (df_master['GPA'] > 4)) else 'ไม่มี'}")
print(f"- รูปแบบการเขียนคณะ: {df_master['คณะ'].nunique()} แบบ")
print(f"- รูปแบบการเขียนเพศ: {df_master['เพศ'].nunique()} แบบ")
# Out:
# ==================================================
# 🎯 ข้อมูลหลัก (Master Dataset) ที่จะใช้ตลอดบทเรียน
# ==================================================
#    รหัสนักศึกษา      ชื่อ   อายุ     เพศ             คณะ   GPA  ส่วนสูง_cm  \
# 0         64001     สมชาย   20.0     ชาย     วิทยาศาสตร์  3.21       170.0
# 1         64002    สมหญิง   21.0    หญิง           วิทย์  3.45       165.0
# 2         64003      None    NaN    Male         Science  3.67       175.0
# 3         64004  สมศักดิ์   22.0       ช  คณะวิทยาศาสตร์ -1.00       168.0
# 4         64005      สมใจ   19.0       ญ           วิศวะ  3.89       160.0
# 5         64006     กานต์  150.0     ชาย     Engineering  3.12       172.0
# 6         64007     กิตติ   21.0    หญิง        วิศวกรรม  4.50       158.0
# 7         64008      จิรา   20.0       F      ศิลปศาสตร์  2.98       180.0
# 8         64009    ชนาธิป   23.0       M            Arts  3.34       163.0
# 9         64010      ดารา   21.0    หญิง           ศิลป์  3.56       167.0
# 10        64011      ธีระ    NaN    None            None  3.78         NaN
# 11        64012       นภา   22.0     ชาย           วิทย์   NaN       171.0
# 12        64013     บุญมี   20.0    หญิง           วิศวฯ  3.23       169.0
# 13        64014     ปรีชา   21.0     ชาย    Liberal Arts  3.45       164.0
# 14        64015     พิมพ์   22.0  Female             Sci  3.67       162.0
# 15        64016      ภูมิ   19.0       ช     วิทยาศาสตร์  3.89       173.0
# 16        64017      มานี   20.0       ญ  วิศวกรรมศาสตร์  3.01       166.0
# 17        64018      ยุพา   21.0    หญิง            None  3.23       161.0
# 18        64019     รัตนา    NaN     ชาย      ศิลปศาสตร์   NaN       174.0
# 19        64020     ลัดดา   22.0    None         Science  3.45       168.0
#
#     น้ำหนัก_kg  ชั่วโมงเรียน_ต่อสัปดาห์ วันที่ลงทะเบียน
# 0         65.0                     15.0      2024-01-23
# 1         58.0                     20.0      2024-02-05
# 2          NaN                     25.0      2024-01-13
# 3         70.0                     10.0      2023-12-30
# 4         52.0                     30.0      2024-01-27
# 5         75.0                     12.0      2023-12-23
# 6         48.0                     35.0      2024-01-05
# 7         82.0                     18.0      2024-01-23
# 8         55.0                     22.0      2024-02-11
# 9         60.0                     28.0      2024-01-03
# 10        68.0                      NaN      2024-01-07
# 11         NaN                     16.0      2023-12-26
# 12        72.0                     24.0      2023-12-26
# 13        54.0                     19.0      2024-01-08
# 14        56.0                     26.0      2024-02-06
# 15        78.0                     14.0      2024-01-20
# 16        62.0                     21.0      2024-01-24
# 17        50.0                     27.0      2024-01-08
# 18        76.0                      NaN      2023-12-18
# 19        64.0                     23.0      2024-01-06
#
# 📊 สรุปปัญหาที่พบในข้อมูล:
# - ค่าหายทั้งหมด: 15 ค่า
# - อายุผิดปกติ: [150.]
# - GPA ผิดปกติ: [-1.   4.5]
# - รูปแบบการเขียนคณะ: 14 แบบ
# - รูปแบบการเขียนเพศ: 8 แบบ

# %%
df_master
# Out:
#    รหัสนักศึกษา      ชื่อ   อายุ     เพศ             คณะ   GPA  ส่วนสูง_cm  \
# 0         64001     สมชาย   20.0     ชาย     วิทยาศาสตร์  3.21       170.0
# 1         64002    สมหญิง   21.0    หญิง           วิทย์  3.45       165.0
# 2         64003      None    NaN    Male         Science  3.67       175.0
# 3         64004  สมศักดิ์   22.0       ช  คณะวิทยาศาสตร์ -1.00       168.0
# 4         64005      สมใจ   19.0       ญ           วิศวะ  3.89       160.0
# 5         64006     กานต์  150.0     ชาย     Engineering  3.12       172.0
# 6         64007     กิตติ   21.0    หญิง        วิศวกรรม  4.50       158.0
# 7         64008      จิรา   20.0       F      ศิลปศาสตร์  2.98       180.0
# 8         64009    ชนาธิป   23.0       M            Arts  3.34       163.0
# 9         64010      ดารา   21.0    หญิง           ศิลป์  3.56       167.0
# 10        64011      ธีระ    NaN    None            None  3.78         NaN
# 11        64012       นภา   22.0     ชาย           วิทย์   NaN       171.0
# 12        64013     บุญมี   20.0    หญิง           วิศวฯ  3.23       169.0
# 13        64014     ปรีชา   21.0     ชาย    Liberal Arts  3.45       164.0
# 14        64015     พิมพ์   22.0  Female             Sci  3.67       162.0
# 15        64016      ภูมิ   19.0       ช     วิทยาศาสตร์  3.89       173.0
# 16        64017      มานี   20.0       ญ  วิศวกรรมศาสตร์  3.01       166.0
# 17        64018      ยุพา   21.0    หญิง            None  3.23       161.0
# 18        64019     รัตนา    NaN     ชาย      ศิลปศาสตร์   NaN       174.0
# 19        64020     ลัดดา   22.0    None         Science  3.45       168.0
#
#     น้ำหนัก_kg  ชั่วโมงเรียน_ต่อสัปดาห์ วันที่ลงทะเบียน
# 0         65.0                     15.0      2024-01-23
# 1         58.0                     20.0      2024-02-05
# 2          NaN                     25.0      2024-01-13
# 3         70.0                     10.0      2023-12-30
# 4         52.0                     30.0      2024-01-27
# 5         75.0                     12.0      2023-12-23
# 6         48.0                     35.0      2024-01-05
# 7         82.0                     18.0      2024-01-23
# 8         55.0                     22.0      2024-02-11
# 9         60.0                     28.0      2024-01-03
# 10        68.0                      NaN      2024-01-07
# 11         NaN                     16.0      2023-12-26
# 12        72.0                     24.0      2023-12-26
# 13        54.0                     19.0      2024-01-08
# 14        56.0                     26.0      2024-02-06
# 15        78.0                     14.0      2024-01-20
# 16        62.0                     21.0      2024-01-24
# 17        50.0                     27.0      2024-01-08
# 18        76.0                      NaN      2023-12-18
# 19        64.0                     23.0      2024-01-06

# %% [markdown]
#  ตรวจสอบค่าที่เป็น NaN ทั้งหมดใน DataFrame

# %%
df_master.isnull().sum().sum()
# Out:
# np.int64(15)

# %% [markdown]
#  ตรวจสอบค่าที่ไม่ซ้ำกันเฉพาะ Column คณะ

# %%
df_master['คณะ'].nunique()
# Out:
# 14

# %% [markdown]
#  เก็บสำเนาข้อมูลต้นฉบับ

# %%
df_original = df_master.copy()

# %%
df_original
# Out:
#    รหัสนักศึกษา      ชื่อ   อายุ     เพศ             คณะ   GPA  ส่วนสูง_cm  \
# 0         64001     สมชาย   20.0     ชาย     วิทยาศาสตร์  3.21       170.0
# 1         64002    สมหญิง   21.0    หญิง           วิทย์  3.45       165.0
# 2         64003      None    NaN    Male         Science  3.67       175.0
# 3         64004  สมศักดิ์   22.0       ช  คณะวิทยาศาสตร์ -1.00       168.0
# 4         64005      สมใจ   19.0       ญ           วิศวะ  3.89       160.0
# 5         64006     กานต์  150.0     ชาย     Engineering  3.12       172.0
# 6         64007     กิตติ   21.0    หญิง        วิศวกรรม  4.50       158.0
# 7         64008      จิรา   20.0       F      ศิลปศาสตร์  2.98       180.0
# 8         64009    ชนาธิป   23.0       M            Arts  3.34       163.0
# 9         64010      ดารา   21.0    หญิง           ศิลป์  3.56       167.0
# 10        64011      ธีระ    NaN    None            None  3.78         NaN
# 11        64012       นภา   22.0     ชาย           วิทย์   NaN       171.0
# 12        64013     บุญมี   20.0    หญิง           วิศวฯ  3.23       169.0
# 13        64014     ปรีชา   21.0     ชาย    Liberal Arts  3.45       164.0
# 14        64015     พิมพ์   22.0  Female             Sci  3.67       162.0
# 15        64016      ภูมิ   19.0       ช     วิทยาศาสตร์  3.89       173.0
# 16        64017      มานี   20.0       ญ  วิศวกรรมศาสตร์  3.01       166.0
# 17        64018      ยุพา   21.0    หญิง            None  3.23       161.0
# 18        64019     รัตนา    NaN     ชาย      ศิลปศาสตร์   NaN       174.0
# 19        64020     ลัดดา   22.0    None         Science  3.45       168.0
#
#     น้ำหนัก_kg  ชั่วโมงเรียน_ต่อสัปดาห์ วันที่ลงทะเบียน
# 0         65.0                     15.0      2024-01-23
# 1         58.0                     20.0      2024-02-05
# 2          NaN                     25.0      2024-01-13
# 3         70.0                     10.0      2023-12-30
# 4         52.0                     30.0      2024-01-27
# 5         75.0                     12.0      2023-12-23
# 6         48.0                     35.0      2024-01-05
# 7         82.0                     18.0      2024-01-23
# 8         55.0                     22.0      2024-02-11
# 9         60.0                     28.0      2024-01-03
# 10        68.0                      NaN      2024-01-07
# 11         NaN                     16.0      2023-12-26
# 12        72.0                     24.0      2023-12-26
# 13        54.0                     19.0      2024-01-08
# 14        56.0                     26.0      2024-02-06
# 15        78.0                     14.0      2024-01-20
# 16        62.0                     21.0      2024-01-24
# 17        50.0                     27.0      2024-01-08
# 18        76.0                      NaN      2023-12-18
# 19        64.0                     23.0      2024-01-06

# %% [markdown]
#  บันทึก export ข้อมูลจาก DataFrame df_master ไปเป็นไฟล์ csv

# %%
df_master.to_csv("student.csv", encoding="utf-8", index=False)

# %% [markdown]
# # วิเคราะห์ข้อมูลเบื้องต้น (EDA)

# %%
import pandas as pd

# %%
df = pd.read_csv("student.csv")

# %%
df.shape
# Out:
# (20, 10)

# %%
df.head()
# Out:
#    รหัสนักศึกษา      ชื่อ  อายุ   เพศ             คณะ   GPA  ส่วนสูง_cm  \
# 0         64001     สมชาย  20.0   ชาย     วิทยาศาสตร์  3.21       170.0
# 1         64002    สมหญิง  21.0  หญิง           วิทย์  3.45       165.0
# 2         64003       NaN   NaN  Male         Science  3.67       175.0
# 3         64004  สมศักดิ์  22.0     ช  คณะวิทยาศาสตร์ -1.00       168.0
# 4         64005      สมใจ  19.0     ญ           วิศวะ  3.89       160.0
#
#    น้ำหนัก_kg  ชั่วโมงเรียน_ต่อสัปดาห์ วันที่ลงทะเบียน
# 0        65.0                     15.0      2024-01-23
# 1        58.0                     20.0      2024-02-05
# 2         NaN                     25.0      2024-01-13
# 3        70.0                     10.0      2023-12-30
# 4        52.0                     30.0      2024-01-27

# %% [markdown]
#  วิเคราะห์ข้อมูลใน DataFrame

# %%
print("="*50)
print("📋 ข้อมูลทั่วไปของ Dataset")
print("="*50)
df_master.info()

print("\n" + "="*50)
print("📊 สถิติเชิงพรรณนา")
print("="*50)
print(df_master.describe())
# Out:
# ==================================================
# 📋 ข้อมูลทั่วไปของ Dataset
# ==================================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   รหัสนักศึกษา             20 non-null     object
#  1   ชื่อ                     19 non-null     object
#  2   อายุ                     17 non-null     float64
#  3   เพศ                      18 non-null     object
#  4   คณะ                      18 non-null     object
#  5   GPA                      18 non-null     float64
#  6   ส่วนสูง_cm               19 non-null     float64
#  7   น้ำหนัก_kg               18 non-null     float64
#  8   ชั่วโมงเรียน_ต่อสัปดาห์  18 non-null     float64
#  9   วันที่ลงทะเบียน          20 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), object(4)
# memory usage: 1.7+ KB
#
# ==================================================
# 📊 สถิติเชิงพรรณนา
# ==================================================
#              อายุ        GPA  ส่วนสูง_cm  น้ำหนัก_kg  ชั่วโมงเรียน_ต่อสัปดาห์  \
# count   17.000000  18.000000   19.000000   18.000000                18.000000
# mean    28.470588   3.246111  167.684211   63.611111                21.388889
# min     19.000000  -1.000000  158.000000   48.000000                10.000000
# 25%     20.000000   3.215000  163.500000   55.250000                16.500000
# 50%     21.000000   3.450000  168.000000   63.000000                21.500000
# 75%     22.000000   3.670000  171.500000   71.500000                25.750000
# max    150.000000   4.500000  180.000000   82.000000                35.000000
# std     31.337114   1.123326    5.706260   10.279270                 6.598920
#
#            วันที่ลงทะเบียน
# count                   20
# mean   2024-01-12 12:00:00
# min    2023-12-18 00:00:00
# 25%    2024-01-02 00:00:00
# 50%    2024-01-08 00:00:00
# 75%    2024-01-23 06:00:00
# max    2024-02-11 00:00:00
# std                    NaN

# %% [markdown]
#  ตรวจสอบค่าหายในแต่ละคอลัมน์

# %%
missing_counts = df_master.isnull().sum()
print("\n❌ ค่าหายในแต่ละคอลัมน์:")
for col, count in missing_counts[missing_counts > 0].items():
    percentage = (count / len(df_master)) * 100
    print(f"   - {col}: {count} ค่า ({percentage:.1f}%)")
# Out:
# ❌ ค่าหายในแต่ละคอลัมน์:
#    - ชื่อ: 1 ค่า (5.0%)
#    - อายุ: 3 ค่า (15.0%)
#    - เพศ: 2 ค่า (10.0%)
#    - คณะ: 2 ค่า (10.0%)
#    - GPA: 2 ค่า (10.0%)
#    - ส่วนสูง_cm: 1 ค่า (5.0%)
#    - น้ำหนัก_kg: 2 ค่า (10.0%)
#    - ชั่วโมงเรียน_ต่อสัปดาห์: 2 ค่า (10.0%)

# %% [markdown]
# #  การจัดการข้อมูลหาย

# %% [markdown]
# # ลบแถวที่มีค่าหาย

# %% [markdown]
# สร้างข้อมูลตัวอย่าง 10 คน โดยมี 1 คนที่ไม่กรอกข้อมูล

# %%
data = {
    'ชื่อ': ['pop', 'earth', 'wave', 'Jor', 'Karn', 'Boss', 'Arm', 'Tangmo', 'Mhai', 'Night'],
    'อายุ': [21, 22, 20, 21, None, 22, 21, 20, 21, 22],  # เฉพาะกุลไม่กรอกอายุ
    'GPA': [3.5, 3.2, 2.3, 3.0, 3.7, 3.3, 3.6, 3.4, 3.1, 3.9]
}

# %% [markdown]
# สร้าง DataFrame

# %%
df = pd.DataFrame(data)

# %%
df.shape
# Out:
# (10, 3)

# %%
df.head()
# Out:
#     ชื่อ  อายุ  GPA
# 0    pop  21.0  3.5
# 1  earth  22.0  3.2
# 2   wave  20.0  2.3
# 3    Jor  21.0  3.0
# 4   Karn   NaN  3.7

# %% [markdown]
# ลบแถวที่ไม่กรอกข้อมูล

# %%
df_clean = df.dropna()

# %%
df_clean
# Out:
#      ชื่อ  อายุ  GPA
# 0     pop  21.0  3.5
# 1   earth  22.0  3.2
# 2    wave  20.0  2.3
# 3     Jor  21.0  3.0
# 5    Boss  22.0  3.3
# 6     Arm  21.0  3.6
# 7  Tangmo  20.0  3.4
# 8    Mhai  21.0  3.1
# 9   Night  22.0  3.9

# %%
df
# Out:
#      ชื่อ  อายุ  GPA
# 0     pop  21.0  3.5
# 1   earth  22.0  3.2
# 2    wave  20.0  2.3
# 3     Jor  21.0  3.0
# 4    Karn   NaN  3.7
# 5    Boss  22.0  3.3
# 6     Arm  21.0  3.6
# 7  Tangmo  20.0  3.4
# 8    Mhai  21.0  3.1
# 9   Night  22.0  3.9

# %% [markdown]
# # เติมค่าด้วยค่าเฉลี่ย

# %% [markdown]
# สร้างข้อมูลตัวอย่าง

# %%
data = {
    'ชื่อ': ['Ood', 'Just', 'Pert', 'Jacky', 'Resoa'],
    'ส่วนสูง': [171, None, 180, 165, 178]  # สมหญิงไม่ได้กรอกอายุ
}
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#     ชื่อ  ส่วนสูง
# 0    Ood    171.0
# 1   Just      NaN
# 2   Pert    180.0
# 3  Jacky    165.0
# 4  Resoa    178.0

# %% [markdown]
# ค่าเฉลี่ยของ Column อายุใน DataFrame

# %%
mean_height = df['ส่วนสูง'].mean()

# %%
mean_height
# Out:
# np.float64(173.5)

# %% [markdown]
# แทนที่ค่าที่เป็น NaN ด้วยค่าเฉลี่ยอายุ

# %%
# df['อายุ'].fillna(mean_age, inplace=True)
df['ส่วนสูง'] = df['ส่วนสูง'].fillna(mean_height)

# %%
df
# Out:
#     ชื่อ  ส่วนสูง
# 0    Ood    171.0
# 1   Just    173.5
# 2   Pert    180.0
# 3  Jacky    165.0
# 4  Resoa    178.0

# %% [markdown]
# # เติมค่าด้วยค่าที่พบบ่อยที่สุด

# %%
data = {
    'ชื่อ': ['Monalisa', 'Odin', 'Sandman', 'Thanos', 'Fitness'],
    'คณะ': ['วิทยาศาสตร์', 'วิทยาศาสตร์', None, 'ศิลปศาสตร์', 'วิทย์']
}

# %% [markdown]
# สร้าง DataFrame

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#        ชื่อ          คณะ
# 0  Monalisa  วิทยาศาสตร์
# 1      Odin  วิทยาศาสตร์
# 2   Sandman         None
# 3    Thanos   ศิลปศาสตร์
# 4   Fitness        วิทย์

# %% [markdown]
# แทนที่ค่าที่เป็น NaN ด้วยค่าที่พบบ่อยที่สุด และเปลี่ยนแปลงข้อมูลโดยตรง

# %%
df['คณะ'].fillna(df['คณะ'].mode()[0], inplace=True)

# %%
df
# Out:
#        ชื่อ          คณะ
# 0  Monalisa  วิทยาศาสตร์
# 1      Odin  วิทยาศาสตร์
# 2   Sandman  วิทยาศาสตร์
# 3    Thanos   ศิลปศาสตร์
# 4   Fitness        วิทย์

# %% [markdown]
# #  การทำให้ข้อมูลเป็นมาตรฐาน

# %%
def standardize_faculty(name):
    if name in ['วิทยาศาสตร์', 'วิทย์', 'Science', 'คณะวิทยาศาสตร์']:
        return 'วิทยาศาสตร์'
    elif name in ['ศิลปศาสตร์', 'ศิลป์', 'Arts']:
        return 'ศิลปศาสตร์'
    else:
        return name

# %% [markdown]
# ใช้ func .apply ปรับปรุงข้อมูลให้เป็นรูปแบบเดียวกัน และสร้างคอลัมน์ใหม่มาเก็บ

# %%
df['คณะ_มาตรฐาน'] = df['คณะ'].apply(standardize_faculty)

# %%
df['คณะ_มาตรฐาน']
# Out:
# 0    วิทยาศาสตร์
# 1    วิทยาศาสตร์
# 2    วิทยาศาสตร์
# 3     ศิลปศาสตร์
# 4    วิทยาศาสตร์
# Name: คณะ_มาตรฐาน, dtype: object

# %% [markdown]
# # การจัดการค่าผิดปกติ

# %%
data = {
    'ชื่อ': ['Jotaro', 'Kakashi', 'Naruto', 'Sasuke', 'Nobita',
             'Doraemon', 'Luffy', 'Zoro', 'Rudo', 'Denji'],
    'อายุ': [20, 21, 22, 19, 20, 150, 21, 22, 23, 18]  # 150 คือค่าผิดปกติ
}
df = pd.DataFrame(data)

# %%
df.head(10)
# Out:
#        ชื่อ  อายุ
# 0    Jotaro    20
# 1   Kakashi    21
# 2    Naruto    22
# 3    Sasuke    19
# 4    Nobita    20
# 5  Doraemon   150
# 6     Luffy    21
# 7      Zoro    22
# 8      Rudo    23
# 9     Denji    18

# %%
print(f"\nค่าเฉลี่ยอายุ (รวมค่าผิดปกติ) - {df['อายุ'].mean():.2f}")
# Out:
# ค่าเฉลี่ยอายุ (รวมค่าผิดปกติ) - 33.60

# %%
Q1 = df['อายุ'].quantile(0.25)
Q3 = df['อายุ'].quantile(0.75)

# %%
Q1, Q3
# Out:
# (np.float64(20.0), np.float64(22.0))

# %% [markdown]
# Interquartile Range ช่วงระหว่าง Q1 และ Q3

# %%
IQR = Q3 - Q1

# %%
IQR
# Out:
# np.float64(2.0)

# %%
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %% [markdown]
# ขอบเขตล่างและบนสำหรับตัดสินว่าค่าใดเป็นค่าผิดปกติ

# %%
lower_bound, upper_bound
# Out:
# (np.float64(17.0), np.float64(25.0))

# %% [markdown]
# กรองค่าผิดปกติ

# %%
df_no_outliers = df[(df['อายุ'] >= lower_bound) & (df['อายุ'] <= upper_bound)]

# %%
df_no_outliers
# Out:
#       ชื่อ  อายุ
# 0   Jotaro    20
# 1  Kakashi    21
# 2   Naruto    22
# 3   Sasuke    19
# 4   Nobita    20
# 6    Luffy    21
# 7     Zoro    22
# 8     Rudo    23
# 9    Denji    18

# %%
(df['อายุ'] >= lower_bound) & (df['อายุ'] <= upper_bound)
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5    False
# 6     True
# 7     True
# 8     True
# 9     True
# Name: อายุ, dtype: bool

# %% [markdown]
# # One-Hot Encoding แปลงข้อมูลประเภทเป็นตัวเลข

# %%
data = pd.DataFrame({
    'ชื่อ': ['Rimuru', 'Banana', 'Castorice', 'Dante'],
    'คณะ': ['วิทย์', 'ศิลป์', 'วิทย์', 'วิศวะ']
})

# %% [markdown]
# ทำ One-Hot Encoding

# %%
data_encoded = pd.get_dummies(data, columns=['คณะ'])

# %%
data_encoded*1
# Out:
#         ชื่อ  คณะ_วิทย์  คณะ_วิศวะ  คณะ_ศิลป์
# 0     Rimuru          1          0          0
# 1     Banana          0          0          1
# 2  Castorice          1          0          0
# 3      Dante          0          1          0

# %% [markdown]
# # การสร้าง Feature จากวันเวลา

# %% [markdown]
# ข้อมูลการซื้อกาแฟ

# %%
coffee_data = pd.DataFrame({
    'วันเวลา': pd.to_datetime(['2024-01-15 07:30', '2024-01-15 12:00',
                               '2024-01-15 16:30', '2024-01-16 08:00']),
    'ยอดขาย': [1500, 3200, 2100, 1800]
})

# %%
coffee_data
# Out:
#               วันเวลา  ยอดขาย
# 0 2024-01-15 07:30:00    1500
# 1 2024-01-15 12:00:00    3200
# 2 2024-01-15 16:30:00    2100
# 3 2024-01-16 08:00:00    1800

# %% [markdown]
# สร้าง features ใหม่
# .dt.hour ดึงชั่วโมงจาก datetime,
# .dt.day_name() ดึงชื่อวันในสัปดาห์

# %%
coffee_data['ชั่วโมง'] = coffee_data['วันเวลา'].dt.hour
coffee_data['วันในสัปดาห์'] = coffee_data['วันเวลา'].dt.day_name()

# %%
coffee_data
# Out:
#               วันเวลา  ยอดขาย  ชั่วโมง วันในสัปดาห์
# 0 2024-01-15 07:30:00    1500        7       Monday
# 1 2024-01-15 12:00:00    3200       12       Monday
# 2 2024-01-15 16:30:00    2100       16       Monday
# 3 2024-01-16 08:00:00    1800        8      Tuesday

# %% [markdown]
# แบ่งข้อมูลตัวเลขเป็นช่วง bins และใส่ label ให้แต่ละช่วง

# %%
coffee_data['ช่วงเวลา'] = pd.cut(coffee_data['ชั่วโมง'],
                                  bins=[0, 10, 14, 18, 24],
                                  labels=['เช้า', 'กลางวัน', 'บ่าย', 'เย็น'])

# %%
coffee_data[['วันเวลา', 'ช่วงเวลา', 'ยอดขาย']]
# Out:
#               วันเวลา ช่วงเวลา  ยอดขาย
# 0 2024-01-15 07:30:00     เช้า    1500
# 1 2024-01-15 12:00:00  กลางวัน    3200
# 2 2024-01-15 16:30:00     บ่าย    2100
# 3 2024-01-16 08:00:00     เช้า    1800

# %% [markdown]
# #การรวม Features

# %% [markdown]
# สร้าง BMI จากส่วนสูงและน้ำหนัก

# %%
student_health = pd.DataFrame({
    'ชื่อ': ['Nova', 'Fire', 'Witter'],
    'ส่วนสูง_cm': [170, 165, 175],
    'น้ำหนัก_kg': [65, 55, 80]
})

# %%
student_health['BMI'] = student_health['น้ำหนัก_kg'] / (student_health['ส่วนสูง_cm']/100)**2

# %% [markdown]
# สร้าง BMI

# %%
student_health['สุขภาพ'] = pd.cut(student_health['BMI'],
                                   bins=[0, 18.5, 25, 30, 100],
                                   labels=['ผอม', 'ปกติ', 'อ้วน', 'อ้วนมาก'])

# %%
student_health
# Out:
#      ชื่อ  ส่วนสูง_cm  น้ำหนัก_kg        BMI สุขภาพ
# 0    Nova         170          65  22.491349   ปกติ
# 1    Fire         165          55  20.202020   ปกติ
# 2  Witter         175          80  26.122449   อ้วน

# %% [markdown]
# ข้อมูลดิบที่มีปัญหา

# %%
raw_data = {
    'รหัสนักศึกษา': ['64001', '64002', '64003', '64004', '64005'],
    'ชื่อ': ['Jack', 'Rose', None, 'Peter', 'Seek'],
    'คณะ': ['วิทย์', 'ศิลปศาสตร์', 'วิทยาศาสตร์', 'Arts', 'วิศวะ'],
    'ชั้นปี': [2, 3, 2, None, 4],
    'GPA': [3.2, 3.8, -1, 2.9, 4.5],  # -1 และ 4.5 ผิดปกติ
    'กิจกรรม': ['กีฬา', 'ดนตรี', 'กีฬา,ดนตรี', None, 'อาสา'],
    'เวลาเข้าร่วม': ['08:00', '9.30', '08:30', '08:00', None]
}

# %% [markdown]
# แปลง dictionary เป็น DataFrame

# %%
df_student = pd.DataFrame(raw_data)

# %%
df_student
# Out:
#   รหัสนักศึกษา   ชื่อ          คณะ  ชั้นปี  GPA     กิจกรรม เวลาเข้าร่วม
# 0        64001   Jack        วิทย์     2.0  3.2        กีฬา        08:00
# 1        64002   Rose   ศิลปศาสตร์     3.0  3.8       ดนตรี         9.30
# 2        64003   None  วิทยาศาสตร์     2.0 -1.0  กีฬา,ดนตรี        08:30
# 3        64004  Peter         Arts     NaN  2.9        None        08:00
# 4        64005   Seek        วิศวะ     4.0  4.5        อาสา         None

# %% [markdown]
# # ขั้นตอนการทำความสะอาดข้อมูล

# %% [markdown]
# ทำให้ชื่อคณะเป็นมาตรฐาน

# %%
faculty_mapping = {
    'วิทย์': 'วิทยาศาสตร์',
    'วิทยาศาสตร์': 'วิทยาศาสตร์',
    'ศิลปศาสตร์': 'ศิลปศาสตร์',
    'Arts': 'ศิลปศาสตร์',
    'วิศวะ': 'วิศวกรรมศาสตร์'
}

# %%
faculty_mapping
# Out:
# {'วิทย์': 'วิทยาศาสตร์',
#  'วิทยาศาสตร์': 'วิทยาศาสตร์',
#  'ศิลปศาสตร์': 'ศิลปศาสตร์',
#  'Arts': 'ศิลปศาสตร์',
#  'วิศวะ': 'วิศวกรรมศาสตร์'}

# %%
df_student['คณะ'] = df_student['คณะ'].map(faculty_mapping)

# %%
df_student
# Out:
#   รหัสนักศึกษา   ชื่อ             คณะ  ชั้นปี  GPA     กิจกรรม เวลาเข้าร่วม
# 0        64001   Jack     วิทยาศาสตร์     2.0  3.2        กีฬา        08:00
# 1        64002   Rose      ศิลปศาสตร์     3.0  3.8       ดนตรี         9.30
# 2        64003   None     วิทยาศาสตร์     2.0 -1.0  กีฬา,ดนตรี        08:30
# 3        64004  Peter      ศิลปศาสตร์     NaN  2.9        None        08:00
# 4        64005   Seek  วิศวกรรมศาสตร์     4.0  4.5        อาสา         None

# %% [markdown]
# แปลงเวลาให้เป็นรูปแบบเดียวกัน

# %%
def standardize_time(time_str):
    if pd.isna(time_str):
        return '08:00'  # ค่าเริ่มต้น
    time_str = str(time_str).replace('.', ':')
    if len(time_str.split(':')[0]) == 1:
        time_str = '0' + time_str
    return time_str

# %%
df_student['เวลาเข้าร่วม'] = df_student['เวลาเข้าร่วม'].apply(standardize_time)

# %%
df_student
# Out:
#   รหัสนักศึกษา   ชื่อ             คณะ  ชั้นปี  GPA     กิจกรรม เวลาเข้าร่วม
# 0        64001   Jack     วิทยาศาสตร์     2.0  3.2        กีฬา        08:00
# 1        64002   Rose      ศิลปศาสตร์     3.0  3.8       ดนตรี        09:30
# 2        64003   None     วิทยาศาสตร์     2.0 -1.0  กีฬา,ดนตรี        08:30
# 3        64004  Peter      ศิลปศาสตร์     NaN  2.9        None        08:00
# 4        64005   Seek  วิศวกรรมศาสตร์     4.0  4.5        อาสา        08:00

# %% [markdown]
# # การสร้าง Features ใหม่

# %% [markdown]
# แปลงเวลาเป็นช่วงเวลา

# %%
df_student['ชั่วโมง'] = pd.to_datetime(df_student['เวลาเข้าร่วม'], format='%H:%M').dt.hour
df_student['ช่วงเวลา'] = pd.cut(df_student['ชั่วโมง'],
                                 bins=[0, 9, 12, 24],
                                 labels=['เช้า', 'สาย', 'บ่าย'])

# %% [markdown]
# นับจำนวนกิจกรรม

# %%
df_student['จำนวนกิจกรรม'] = df_student['กิจกรรม'].apply(
    lambda x: len(str(x).split(',')) if str(x) != 'ไม่ได้เข้าร่วม' else 0
)

# %% [markdown]
# จัดกลุ่มผลการเรียน

# %%
df_student['ระดับผลการเรียน'] = pd.cut(df_student['GPA'],
                                        bins=[0, 2.0, 3.0, 3.5, 4.0],
                                        labels=['ต่ำ', 'ปานกลาง', 'ดี', 'ดีมาก'])

# %% [markdown]
# One-Hot Encoding สำหรับคณะ

# %%
df_encoded = pd.get_dummies(df_student, columns=['คณะ'], prefix='คณะ')

# %%
df_encoded[['รหัสนักศึกษา', 'ช่วงเวลา', 'จำนวนกิจกรรม', 'ระดับผลการเรียน']]
# Out:
#   รหัสนักศึกษา ช่วงเวลา  จำนวนกิจกรรม ระดับผลการเรียน
# 0        64001     เช้า             1              ดี
# 1        64002     เช้า             1           ดีมาก
# 2        64003     เช้า             2             NaN
# 3        64004     เช้า             1         ปานกลาง
# 4        64005     เช้า             1             NaN

# %% [markdown]
# แปลง Series หรือ Index ให้กลายเป็น list

# %%
df_encoded.columns.tolist()
# Out:
# ['รหัสนักศึกษา',
#  'ชื่อ',
#  'ชั้นปี',
#  'GPA',
#  'กิจกรรม',
#  'เวลาเข้าร่วม',
#  'ชั่วโมง',
#  'ช่วงเวลา',
#  'จำนวนกิจกรรม',
#  'ระดับผลการเรียน',
#  'คณะ_วิทยาศาสตร์',
#  'คณะ_วิศวกรรมศาสตร์',
#  'คณะ_ศิลปศาสตร์']
